# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_data = ImageDataGenerator(
    rescale = 1.0/255,
    rotation_range = 20,
    # width_shift_range=0.2,
    # height_shift_range=0.2,
    horizontal_flip = True,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest'
)

# %%
train = train_data.flow_from_directory(
    # 'cat_dog_dataset/train/',
    'catimage/train',
    target_size=(64,64),
    batch_size=1,
    classes=['dogs']
)
# Out:
# Found 1 images belonging to 1 classes.

# %%
next(train)
# Out:
# (array([[[[0.37019405, 0.49450803, 0.22352685],
#           [0.39975756, 0.5203761 , 0.26048124],
#           [0.4206336 , 0.5384617 , 0.2869383 ],
#           ...,
#           [0.40768126, 0.49707907, 0.241136  ],
#           [0.3465381 , 0.48734686, 0.2142668 ],
#           [0.35392228, 0.47867668, 0.21666738]],
#
#          [[0.25925714, 0.39129776, 0.0997222 ],
#           [0.28697294, 0.4199374 , 0.12374255],
#           [0.3157987 , 0.4469121 , 0.15553267],
#           ...,
#           [0.4019259 , 0.4977985 , 0.23969716],
#           [0.34226245, 0.48555058, 0.2121267 ],
#           [0.3568    , 0.47939608, 0.21954507]],
#
#          [[0.18590462, 0.3042915 , 0.02953507],
#           [0.18054572, 0.3099626 , 0.03150563],
#           [0.2082615 , 0.33860227, 0.05552598],
#           ...,
#           [0.39281967, 0.4966032 , 0.23586486],
#           [0.3444207 , 0.48411173, 0.21284612],
#           [0.35967767, 0.48011553, 0.22242276]],
#
#          ...,
#
#          [[0.16684686, 0.31976393, 0.08112567],
#           [0.0765182 , 0.2667856 , 0.03676773],
#           [0.05451533, 0.20631503, 0.02754304],
#           ...,
#           [0.17513031, 0.23519483, 0.14282878],
#           [0.1686633 , 0.21579377, 0.13728562],
#           [0.17873362, 0.23314238, 0.1390924 ]],
#
#          [[0.1877101 , 0.3456631 , 0.10342777],
#           [0.0412665 , 0.23800868, 0.01230737],
#           [0.07302679, 0.21884704, 0.04196481],
#           ...,
#           [0.2399221 , 0.34354785, 0.21017782],
#           [0.19349632, 0.29029283, 0.15857106],
#           [0.18702929, 0.2708918 , 0.1530279 ]],
#
#          [[0.20857336, 0.37156233, 0.12572986],
#           [0.02674638, 0.22174221, 0.00285953],
#           [0.11547271, 0.26345125, 0.0736194 ],
#           ...,
#           [0.4932132 , 0.6053098 , 0.4955059 ],
#           [0.44719553, 0.5586924 , 0.4436884 ],
#           [0.37421063, 0.4829359 , 0.3614649 ]]]], dtype=float32),
#  array([[1.]], dtype=float32))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))

for i in range(12):
    img, _ = next(train)
    plt.subplot(3, 4, i+1)
    plt.imshow(img[0])
    plt.axis('off')

plt.show()
