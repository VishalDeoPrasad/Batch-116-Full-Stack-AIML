# %%
import pandas as pd

data = {
    "Name":["Rahul", "Alena", "Ravi", "Neha"],
    "Age" : [21,24,23,20],
    "City" : ['Delhi', 'Mumbai', 'Pune', 'Bangalore'],
    "Marks" :[90, 89, 70, 79]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age       City  Marks
# 0  Rahul   21      Delhi     90
# 1  Alena   24     Mumbai     89
# 2   Ravi   23       Pune     70
# 3   Neha   20  Bangalore     79

# %%
df.head(2)
# Out:
#     Name  Age    City  Marks
# 0  Rahul   21   Delhi     90
# 1  Alena   24  Mumbai     89

# %%
df.head(3)
# Out:
#     Name  Age    City  Marks
# 0  Rahul   21   Delhi     90
# 1  Alena   24  Mumbai     89
# 2   Ravi   23    Pune     70

# %%
df.tail(1)
# Out:
#    Name  Age       City  Marks
# 3  Neha   20  Bangalore     79

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
#  3   Marks   4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df.describe()
# Out:
#              Age      Marks
# count   4.000000   4.000000
# mean   22.000000  82.000000
# std     1.825742   9.416298
# min    20.000000  70.000000
# 25%    20.750000  76.750000
# 50%    22.000000  84.000000
# 75%    23.250000  89.250000
# max    24.000000  90.000000

# %%
df
# Out:
#     Name  Age       City  Marks
# 0  Rahul   21      Delhi     90
# 1  Alena   24     Mumbai     89
# 2   Ravi   23       Pune     70
# 3   Neha   20  Bangalore     79

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Marks'], dtype='object')

# %%
df
# Out:
#     Name  Age       City  Marks
# 0  Rahul   21      Delhi     90
# 1  Alena   24     Mumbai     89
# 2   Ravi   23       Pune     70
# 3   Neha   20  Bangalore     79

# %%
df.shape
# Out:
# (4, 4)

# %%
df
# Out:
#     Name  Age       City  Marks
# 0  Rahul   21      Delhi     90
# 1  Alena   24     Mumbai     89
# 2   Ravi   23       Pune     70
# 3   Neha   20  Bangalore     79

# %%
# df.Name
df['Name']
# Out:
# 0    Rahul
# 1    Alena
# 2     Ravi
# 3     Neha
# Name: Name, dtype: object

# %%
df.Age
# Out:
# 0    21
# 1    24
# 2    23
# 3    20
# Name: Age, dtype: int64

# %%
df.City
# Out:
# 0        Delhi
# 1       Mumbai
# 2         Pune
# 3    Bangalore
# Name: City, dtype: object

# %%
df[['Name', 'Marks']]
# Out:
#     Name  Marks
# 0  Rahul     90
# 1  Alena     89
# 2   Ravi     70
# 3   Neha     79
