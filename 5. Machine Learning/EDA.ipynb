# %%
import pandas as pd
df = pd.read_csv("rapido_data.csv")

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df.tail()
# Out:
#          services        date      time ride_status  \
# 9995         auto  2024-07-01   9:57:20   cancelled
# 9996   auto share  2024-07-10   2:47:20   completed
# 9997   auto share  2024-07-06  23:56:20   cancelled
# 9998  cab premium  2024-07-23   6:10:20   cancelled
# 9999  cab economy  2024-07-20   7:42:20   completed
#
#                               source                destination  duration  \
# 9995  Brigade Road Mota Royal Arcade                Neelasandra       120
# 9996                     Frazer Town        MG Road Cubbon Park        71
# 9997      Brigade Road Church Street  HSR Layout Sector 5 North        71
# 9998           Rajajinagar 2nd Block         HSR Layout Central        26
# 9999                    Hebbal North       HSR Layout Sector 10        88
#
#                  ride_id  distance  ride_charge  misc_charge  total_fare  \
# 9995  RD8489738606219832     10.70          NaN          NaN         NaN
# ...

# %%
df.sample(10)
# Out:
#          services        date      time ride_status  \
# 951        parcel  2024-06-30   5:16:20   cancelled
# 1412    bike lite  2024-07-13   1:22:20   completed
# 1320    bike lite  2024-07-11  21:29:20   completed
# 2261  cab premium  2024-07-13   5:58:20   completed
# 9916  cab economy  2024-07-19  16:34:20   cancelled
# 2781  cab premium  2024-07-06  15:33:20   completed
# 7554  cab economy  2024-07-19   8:05:20   completed
# 5069         bike  2024-07-04   7:49:20   cancelled
# 4925  cab economy  2024-07-21   9:10:20   completed
# 1665   auto share  2024-07-07  20:09:20   cancelled
#
#                           source                destination  duration  \
# 951        Rajajinagar 2nd Block             St. Marks Road        23
# 1412         HSR Layout Sector 8  MG Road Commercial Street        80
# 1320               JP Nagar East      Indiranagar 2nd Stage        36
# 2261  MG Road Anil Kumble Circle                Hebbal West        91
# ...

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.columns
# Out:
# Index(['services', 'date', 'time', 'ride_status', 'source', 'destination',
#        'duration', 'ride_id', 'distance', 'ride_charge', 'misc_charge',
#        'total_fare', 'payment_method'],
#       dtype='object')

# %%
df.dtypes
# Out:
# services           object
# date               object
# time               object
# ride_status        object
# source             object
# destination        object
# duration            int64
# ride_id            object
# distance          float64
# ride_charge       float64
# misc_charge       float64
# total_fare        float64
# payment_method     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   services        10000 non-null  object
#  1   date            10000 non-null  object
#  2   time            10000 non-null  object
#  3   ride_status     10000 non-null  object
#  4   source          10000 non-null  object
#  5   destination     10000 non-null  object
#  6   duration        10000 non-null  int64
#  7   ride_id         10000 non-null  object
#  8   distance        10000 non-null  float64
#  9   ride_charge     4611 non-null   float64
#  10  misc_charge     4611 non-null   float64
#  11  total_fare      4611 non-null   float64
#  12  payment_method  4611 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1015.8+ KB

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df.describe()
# Out:
#            duration      distance  ride_charge  misc_charge   total_fare
# count  10000.000000  10000.000000  4611.000000  4611.000000  4611.000000
# mean      62.210000     25.563203   505.298315    25.206426   530.504741
# std       33.465001     14.199687   285.629503    14.271037   285.880226
# min        5.000000      1.010000    10.840000     0.020000    18.810000
# 25%       33.000000     13.210000   256.330000    12.855000   281.875000
# 50%       62.000000     25.645000   504.510000    25.530000   528.900000
# 75%       92.000000     37.832500   753.895000    37.270000   778.250000
# max      120.000000     49.990000   999.700000    49.990000  1044.290000

# %%
df.total_fare.describe()
# Out:
# count    4611.000000
# mean      530.504741
# std       285.880226
# min        18.810000
# 25%       281.875000
# 50%       528.900000
# 75%       778.250000
# max      1044.290000
# Name: total_fare, dtype: float64

# %%
df[['total_fare', 'misc_charge']].describe()
# Out:
#         total_fare  misc_charge
# count  4611.000000  4611.000000
# mean    530.504741    25.206426
# std     285.880226    14.271037
# min      18.810000     0.020000
# 25%     281.875000    12.855000
# 50%     528.900000    25.530000
# 75%     778.250000    37.270000
# max    1044.290000    49.990000

# %%
df.describe()
# Out:
#            duration      distance  ride_charge  misc_charge   total_fare
# count  10000.000000  10000.000000  4611.000000  4611.000000  4611.000000
# mean      62.210000     25.563203   505.298315    25.206426   530.504741
# std       33.465001     14.199687   285.629503    14.271037   285.880226
# min        5.000000      1.010000    10.840000     0.020000    18.810000
# 25%       33.000000     13.210000   256.330000    12.855000   281.875000
# 50%       62.000000     25.645000   504.510000    25.530000   528.900000
# 75%       92.000000     37.832500   753.895000    37.270000   778.250000
# max      120.000000     49.990000   999.700000    49.990000  1044.290000

# %%
df.describe(include="object")
# Out:
#        services        date     time ride_status                source  \
# count     10000       10000    10000       10000                 10000
# unique        7          31     1438           2                   316
# top        auto  2024-06-30  9:59:20   cancelled  MG Road Naga Theatre
# freq       1479         362       17        5389                    46
#
#                    destination             ride_id payment_method
# count                    10000               10000           4611
# unique                     316               10000              6
# top     Banashankari 9th Stage  RD8660319589404637        QR scan
# freq                        49                   1            797

# %%
df.describe(include="all")
# Out:
#        services        date     time ride_status                source  \
# count     10000       10000    10000       10000                 10000
# unique        7          31     1438           2                   316
# top        auto  2024-06-30  9:59:20   cancelled  MG Road Naga Theatre
# freq       1479         362       17        5389                    46
# mean        NaN         NaN      NaN         NaN                   NaN
# std         NaN         NaN      NaN         NaN                   NaN
# min         NaN         NaN      NaN         NaN                   NaN
# 25%         NaN         NaN      NaN         NaN                   NaN
# 50%         NaN         NaN      NaN         NaN                   NaN
# 75%         NaN         NaN      NaN         NaN                   NaN
# max         NaN         NaN      NaN         NaN                   NaN
#
#                    destination      duration             ride_id  \
# ...

# %%
df.isna().sum()
# Out:
# services             0
# date                 0
# time                 0
# ride_status          0
# source               0
# destination          0
# duration             0
# ride_id              0
# distance             0
# ride_charge       5389
# misc_charge       5389
# total_fare        5389
# payment_method    5389
# dtype: int64

# %%
df.shape
# Out:
# (10000, 13)

# %% [markdown]
# > Move all the rows containing Missing Values

# %%
# df = df.dropna()
df.dropna(axis=0, inplace=True)

# %%
df.shape
# Out:
# (4611, 13)

# %% [markdown]
# > Move all the columns which containing Missing Value

# %%
# df.dropna(axis=1, inplace=True)

# %%
# df.shape

# %%
# count of duplicate row
df.duplicated().sum()
# Out:
# 0

# %%
# to display duplicate rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [services, date, time, ride_status, source, destination, duration, ride_id, distance, ride_charge, misc_charge, total_fare, payment_method]
# Index: []

# %%
# Drop all the duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.columns = df.columns.str.upper()

# %%
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
# 6    bike lite  2024-07-01  22:54:20   completed             Kadubeesanahalli
#
#               destination  duration             ride_id  distance  \
# 0           Richmond Road        99  RD8660319589404637     18.68
# 1           Sahakar Nagar        48  RD4484661533610497     42.55
# 2        Whitefield South       112  RD1526455182706880      5.85
# 4   Brigade Road Eva Mall        44  RD6627722888214728      5.61
# 6  Banashankari 2nd Stage        30  RD1872668675732568     11.61
#
#    ride_charge  misc_charge  total_fare payment_method
# ...

# %%
df.drop(['ride_id'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['services', 'date', 'time', 'ride_status', 'source', 'destination',
#        'duration', 'distance', 'ride_charge', 'misc_charge', 'total_fare',
#        'payment_method'],
#       dtype='object')

# %% [markdown]
# ##### 1. services columns

# %%
df.services.describe()

# %%
df.services.value_counts()

# %%
import seaborn as sns
sns.countplot(data=df, x='services')
# Out:
# <Axes: xlabel='services', ylabel='count'>

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
# 6    bike lite  2024-07-01  22:54:20   completed             Kadubeesanahalli
#
#               destination  duration  distance  ride_charge  misc_charge  \
# 0           Richmond Road        99     18.68        93.09         2.32
# 1           Sahakar Nagar        48     42.55       420.77        11.68
# 2        Whitefield South       112      5.85       247.90        27.45
# 4   Brigade Road Eva Mall        44      5.61       786.30        21.40
# 6  Banashankari 2nd Stage        30     11.61       685.89         6.11
#
#    total_fare payment_method
# 0       95.41     Amazon Pay
# ...
