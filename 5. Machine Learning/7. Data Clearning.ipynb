# %%
import pandas as pd

data = {
    "EmployeeID": [101,102,103,104,105],
    "Age": [25,32,29,41,36],
    "Gender": ["Male","Female","Male","Female","Male"],
    "Department": ["IT","HR","Finance","IT","Marketing"],
    "Salary": [50000,62000,58000,75000,540000,],
    "City": ["Delhi","Mumbai","Bangalore","Hyderabad","Chennai"],
    "Country": ["India","India","India","India","India"],
    "Experience": [2,6,4,10,7],
    "Education": ["Bachelors","Masters","Bachelors","PhD","Masters"],
}

df = pd.DataFrame(data)
df
# Out:
#    EmployeeID  Age  Gender Department  Salary       City Country  Experience  \
# 0         101   25    Male         IT   50000      Delhi   India           2
# 1         102   32  Female         HR   62000     Mumbai   India           6
# 2         103   29    Male    Finance   58000  Bangalore   India           4
# 3         104   41  Female         IT   75000  Hyderabad   India          10
# 4         105   36    Male  Marketing  540000    Chennai   India           7
#
#    Education
# 0  Bachelors
# 1    Masters
# 2  Bachelors
# 3        PhD
# 4    Masters

# %%
import pandas as pd
df = pd.read_csv("Big_Bazaar.csv")
df
# Out:
#       branch_code        city  gender     product_category  unit_price  \
# 0          FAR_23   Faridabad  Female           Home Decor         NaN
# 1          GUW_44    Guwahati    Male         Frozen Foods         NaN
# 2          PAT_17       Patna  Female               Bakery       88.77
# 3          MEE_24      Meerut    Male               Snacks       77.40
# 4          THA_14       Thane    Male         Pet Supplies      751.38
# ...           ...         ...     ...                  ...         ...
# 59995      GUW_44    Guwahati    Male         Frozen Foods      224.40
# 59996      MEE_24      Meerut  Female         Pet Supplies      824.22
# 59997         NaN   Faridabad  Female       Dairy Products      759.40
# 59998      ALL_34   Allahabad  Female  Fruits & Vegetables      370.77
# 59999      CHA_45  Chandigarh  Female  Fruits & Vegetables      134.36
#
#        quantity  total_price     gst payment_method  rating        date  \
# ...

# %%
df.shape
# Out:
# (60000, 13)

# %%
df.isnull().sum()
# Out:
# branch_code         3120
# city                2989
# gender              3011
# product_category    2997
# unit_price          2993
# quantity            3007
# total_price         2992
# gst                 3019
# payment_method      2999
# rating              3000
# date                2993
# time                2991
# day                 2994
# dtype: int64

# %%
df.to_csv("Big_Bazaar.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   branch_code       56880 non-null  object
#  1   city              57011 non-null  object
#  2   gender            56989 non-null  object
#  3   product_category  57003 non-null  object
#  4   unit_price        57007 non-null  float64
#  5   quantity          56993 non-null  float64
#  6   total_price       57008 non-null  float64
#  7   gst               56981 non-null  float64
#  8   payment_method    57001 non-null  object
#  9   rating            57000 non-null  float64
#  10  date              57007 non-null  object
#  11  time              57009 non-null  object
#  12  day               57006 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 6.0+ MB

# %%
df.head()
# Out:
#   branch_code       city  gender product_category  unit_price  quantity  \
# 0      FAR_23  Faridabad  Female       Home Decor         NaN       2.0
# 1      GUW_44   Guwahati    Male     Frozen Foods         NaN       6.0
# 2      PAT_17      Patna  Female           Bakery       88.77       NaN
# 3      MEE_24     Meerut    Male           Snacks       77.40       3.0
# 4      THA_14      Thane    Male     Pet Supplies      751.38       4.0
#
#    total_price     gst payment_method  rating        date      time       day
# 0      1294.08  232.93            NaN     2.6  2024-07-16  15:46:42       NaN
# 1      5804.46     NaN       Mobikwik     2.2  2024-06-15       NaN  Saturday
# 2       266.31   47.94           Cash     3.8  2024-12-14  14:27:15  Saturday
# 3       232.20   41.80        PhonePe     1.3  2025-03-16  22:10:38    Sunday
# 4      3005.52  540.99     Debit Card     3.0  2024-08-04  03:57:11    Sunday

# %%
df.isnull().sum()
# Out:
# branch_code         3120
# city                2989
# gender              3011
# product_category    2997
# unit_price          2993
# quantity            3007
# total_price         2992
# gst                 3019
# payment_method      2999
# rating              3000
# date                2993
# time                2991
# day                 2994
# dtype: int64

# %%
# df.dropna(inplace=True)

# %%
# df.isnull().sum()

# %%
df.shape
# Out:
# (60000, 13)

# %%
df.fillna(0)
# Out:
#       branch_code        city  gender     product_category  unit_price  \
# 0          FAR_23   Faridabad  Female           Home Decor        0.00
# 1          GUW_44    Guwahati    Male         Frozen Foods        0.00
# 2          PAT_17       Patna  Female               Bakery       88.77
# 3          MEE_24      Meerut    Male               Snacks       77.40
# 4          THA_14       Thane    Male         Pet Supplies      751.38
# ...           ...         ...     ...                  ...         ...
# 59995      GUW_44    Guwahati    Male         Frozen Foods      224.40
# 59996      MEE_24      Meerut  Female         Pet Supplies      824.22
# 59997           0   Faridabad  Female       Dairy Products      759.40
# 59998      ALL_34   Allahabad  Female  Fruits & Vegetables      370.77
# 59999      CHA_45  Chandigarh  Female  Fruits & Vegetables      134.36
#
#        quantity  total_price     gst payment_method  rating        date  \
# ...

# %%
df.branch_code.isnull().sum()
# Out:
# 3120

# %%
df.branch_code.nunique()
# Out:
# 48

# %%
df.branch_code.value_counts()
# Out:
# branch_code
# SRI_29    1286
# SOL_46    1251
# HOW_36    1248
# AMR_32    1242
# NAS_22    1239
# VAS_27    1231
# LUD_20    1216
# DEL_00    1215
# HYD_05    1213
# RAI_43    1212
# KAL_26    1206
# VIS_16    1204
# IND_13    1204
# JAI_08    1200
# ALL_34    1200
# MEE_24    1198
# GWA_39    1197
# PAT_17    1195
# GHA_19    1193
# AGR_21    1191
# THA_14    1185
# NAV_33    1185
# VAD_18    1184
# JOD_41    1184
# CHE_03    1183
# BAN_04    1182
# SUR_09    1181
# GUW_44    1181
# FAR_23    1179
# NAG_12    1178
# AUR_30    1178
# RAJ_25    1175
# KAN_11    1174
# RAN_35    1174
# BHO_15    1173
# MAD_42    1166
# AHM_06    1164
# NOI_40    1164
# HUB_47    1157
# DHA_31    1154
# CHA_45    1148
# JAB_38    1148
# LUC_10    1143
# KOL_02    1131
# VAR_28    1121
# COI_37    1121
# MUM_01    1116
# PUN_07    1110
# Name: count, dtype: int64

# %%
val = df.branch_code.mode()
val[0]
# Out:
# 'SRI_29'

# %%
df.branch_code.fillna(val[0], inplace=True)
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_13912\4043337536.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.branch_code.fillna(val[0], inplace=True)

# %%
df.branch_code.isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   branch_code       city  gender product_category  unit_price  quantity  \
# 0      FAR_23  Faridabad  Female       Home Decor         NaN       2.0
# 1      GUW_44   Guwahati    Male     Frozen Foods         NaN       6.0
# 2      PAT_17      Patna  Female           Bakery       88.77       NaN
# 3      MEE_24     Meerut    Male           Snacks       77.40       3.0
# 4      THA_14      Thane    Male     Pet Supplies      751.38       4.0
#
#    total_price     gst payment_method  rating        date      time       day
# 0      1294.08  232.93            NaN     2.6  2024-07-16  15:46:42       NaN
# 1      5804.46     NaN       Mobikwik     2.2  2024-06-15       NaN  Saturday
# 2       266.31   47.94           Cash     3.8  2024-12-14  14:27:15  Saturday
# 3       232.20   41.80        PhonePe     1.3  2025-03-16  22:10:38    Sunday
# 4      3005.52  540.99     Debit Card     3.0  2024-08-04  03:57:11    Sunday

# %%
df.city.isnull().sum()
# Out:
# 2989

# %%
val = df.city.mode()
val[0]
# Out:
# 'Srinagar'

# %%
df.city.fillna(val[0], inplace=True)
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_13912\3818017380.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.city.fillna(val[0], inplace=True)

# %%
df.city.isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   branch_code       city  gender product_category  unit_price  quantity  \
# 0      FAR_23  Faridabad  Female       Home Decor         NaN       2.0
# 1      GUW_44   Guwahati    Male     Frozen Foods         NaN       6.0
# 2      PAT_17      Patna  Female           Bakery       88.77       NaN
# 3      MEE_24     Meerut    Male           Snacks       77.40       3.0
# 4      THA_14      Thane    Male     Pet Supplies      751.38       4.0
#
#    total_price     gst payment_method  rating        date      time       day
# 0      1294.08  232.93            NaN     2.6  2024-07-16  15:46:42       NaN
# 1      5804.46     NaN       Mobikwik     2.2  2024-06-15       NaN  Saturday
# 2       266.31   47.94           Cash     3.8  2024-12-14  14:27:15  Saturday
# 3       232.20   41.80        PhonePe     1.3  2025-03-16  22:10:38    Sunday
# 4      3005.52  540.99     Debit Card     3.0  2024-08-04  03:57:11    Sunday

# %%
df.gender.isnull().sum()
# Out:
# 3011

# %%
val = df.gender.mode()
val[0]
# Out:
# 'Female'

# %%
df.gender.fillna(val[0], inplace=True)
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_13912\1818949269.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.gender.fillna(val[0], inplace=True)

# %%
df.gender.isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   branch_code       city  gender product_category  unit_price  quantity  \
# 0      FAR_23  Faridabad  Female       Home Decor         NaN       2.0
# 1      GUW_44   Guwahati    Male     Frozen Foods         NaN       6.0
# 2      PAT_17      Patna  Female           Bakery       88.77       NaN
# 3      MEE_24     Meerut    Male           Snacks       77.40       3.0
# 4      THA_14      Thane    Male     Pet Supplies      751.38       4.0
#
#    total_price     gst payment_method  rating        date      time       day
# 0      1294.08  232.93            NaN     2.6  2024-07-16  15:46:42       NaN
# 1      5804.46     NaN       Mobikwik     2.2  2024-06-15       NaN  Saturday
# 2       266.31   47.94           Cash     3.8  2024-12-14  14:27:15  Saturday
# 3       232.20   41.80        PhonePe     1.3  2025-03-16  22:10:38    Sunday
# 4      3005.52  540.99     Debit Card     3.0  2024-08-04  03:57:11    Sunday

# %%
df.unit_price.isnull().sum()
# Out:
# 2993

# %%
val = df.unit_price.mean()
val = round(val, 2)
val
# Out:
# 677.74

# %%
df.unit_price.fillna(val, inplace=True)
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_13912\1877510489.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.unit_price.fillna(val, inplace=True)

# %%
df.unit_price.isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   branch_code       city  gender product_category  unit_price  quantity  \
# 0      FAR_23  Faridabad  Female       Home Decor      677.74       2.0
# 1      GUW_44   Guwahati    Male     Frozen Foods      677.74       6.0
# 2      PAT_17      Patna  Female           Bakery       88.77       NaN
# 3      MEE_24     Meerut    Male           Snacks       77.40       3.0
# 4      THA_14      Thane    Male     Pet Supplies      751.38       4.0
#
#    total_price     gst payment_method  rating        date      time       day
# 0      1294.08  232.93            NaN     2.6  2024-07-16  15:46:42       NaN
# 1      5804.46     NaN       Mobikwik     2.2  2024-06-15       NaN  Saturday
# 2       266.31   47.94           Cash     3.8  2024-12-14  14:27:15  Saturday
# 3       232.20   41.80        PhonePe     1.3  2025-03-16  22:10:38    Sunday
# 4      3005.52  540.99     Debit Card     3.0  2024-08-04  03:57:11    Sunday

# %%
df.quantity.isnull().sum()
# Out:
# 3007

# %%
val = df.quantity.median()
val
# Out:
# 6.0

# %%
# df.quantity.fillna(val, inplace=True)
df.quantity = df.quantity.fillna(val)

# %%
df.quantity.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# branch_code            0
# city                   0
# gender                 0
# product_category    2997
# unit_price             0
# quantity               0
# total_price         2992
# gst                 3019
# payment_method      2999
# rating              3000
# date                2993
# time                2991
# day                 2994
# dtype: int64

# %%
df.product_category.isnull().sum()
# Out:
# 2997

# %%
df.product_category.fillna(method="ffill", inplace=True)
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_13912\1060332187.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.product_category.fillna(method="ffill", inplace=True)
# C:\Users\visha\AppData\Local\Temp\ipykernel_13912\1060332187.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.product_category.fillna(method="ffill", inplace=True)

# %%
df.product_category.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# branch_code            0
# city                   0
# gender                 0
# product_category       0
# unit_price             0
# quantity               0
# total_price         2992
# gst                 3019
# payment_method      2999
# rating              3000
# date                2993
# time                2991
# day                 2994
# dtype: int64

# %%
df.payment_method.fillna(method="bfill", inplace=True)
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_13912\517301043.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.payment_method.fillna(method="bfill", inplace=True)
# C:\Users\visha\AppData\Local\Temp\ipykernel_13912\517301043.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.payment_method.fillna(method="bfill", inplace=True)

# %%
df.payment_method.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# branch_code            0
# city                   0
# gender                 0
# product_category       0
# unit_price             0
# quantity               0
# total_price         2992
# gst                 3019
# payment_method         0
# rating              3000
# date                2993
# time                2991
# day                 2994
# dtype: int64

# %%
df.rating.isnull().sum()
# Out:
# 3000

# %%
# df.rating.interpolate(inplace=True)

# %%
df.rating.isnull().sum()
# Out:
# 3000

# %%
df.isnull().sum()
# Out:
# branch_code            0
# city                   0
# gender                 0
# product_category       0
# unit_price             0
# quantity               0
# total_price         2992
# gst                 3019
# payment_method         0
# rating              3000
# date                2993
# time                2991
# day                 2994
# dtype: int64

# %%
df.head()
# Out:
#   branch_code       city  gender product_category  unit_price  quantity  \
# 0      FAR_23  Faridabad  Female       Home Decor      677.74       2.0
# 1      GUW_44   Guwahati    Male     Frozen Foods      677.74       6.0
# 2      PAT_17      Patna  Female           Bakery       88.77       6.0
# 3      MEE_24     Meerut    Male           Snacks       77.40       3.0
# 4      THA_14      Thane    Male     Pet Supplies      751.38       4.0
#
#    total_price     gst payment_method  rating        date      time       day
# 0      1294.08  232.93       Mobikwik     2.6  2024-07-16  15:46:42       NaN
# 1      5804.46     NaN       Mobikwik     2.2  2024-06-15       NaN  Saturday
# 2       266.31   47.94           Cash     3.8  2024-12-14  14:27:15  Saturday
# 3       232.20   41.80        PhonePe     1.3  2025-03-16  22:10:38    Sunday
# 4      3005.52  540.99     Debit Card     3.0  2024-08-04  03:57:11    Sunday

# %%
df.total_price = df.unit_price * df.quantity

# %%
df.head()
# Out:
#   branch_code       city  gender product_category  unit_price  quantity  \
# 0      FAR_23  Faridabad  Female       Home Decor      677.74       2.0
# 1      GUW_44   Guwahati    Male     Frozen Foods      677.74       6.0
# 2      PAT_17      Patna  Female           Bakery       88.77       6.0
# 3      MEE_24     Meerut    Male           Snacks       77.40       3.0
# 4      THA_14      Thane    Male     Pet Supplies      751.38       4.0
#
#    total_price     gst payment_method  rating        date      time       day
# 0      1355.48  232.93       Mobikwik     2.6  2024-07-16  15:46:42       NaN
# 1      4066.44     NaN       Mobikwik     2.2  2024-06-15       NaN  Saturday
# 2       532.62   47.94           Cash     3.8  2024-12-14  14:27:15  Saturday
# 3       232.20   41.80        PhonePe     1.3  2025-03-16  22:10:38    Sunday
# 4      3005.52  540.99     Debit Card     3.0  2024-08-04  03:57:11    Sunday

# %%
df.gst.isnull().sum()
# Out:
# 3019

# %%
df.gst = df.total_price * 0.05

# %%
df.gst.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# branch_code            0
# city                   0
# gender                 0
# product_category       0
# unit_price             0
# quantity               0
# total_price            0
# gst                    0
# payment_method         0
# rating              3000
# date                2993
# time                2991
# day                 2994
# dtype: int64

# %%
df.date
# Out:
# 0        2024-07-16
# 1        2024-06-15
# 2        2024-12-14
# 3        2025-03-16
# 4        2024-08-04
#             ...
# 59995    2024-12-15
# 59996    2025-04-21
# 59997    2024-02-12
# 59998    2024-09-10
# 59999    2024-10-13
# Name: date, Length: 60000, dtype: object

# %%
df.rating.isnull().sum()
# Out:
# 3000

# %%
from sklearn.impute import KNNImputer
im = KNNImputer(n_neighbors=3)
# df.rating = im.fit_transform(df[['rating']])

# %%
df.rating.isnull().sum()
# Out:
# 3000

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

im = IterativeImputer()
df.rating = im.fit_transform(df[['rating']])

# %%
df.head()
# Out:
#   branch_code       city  gender product_category  unit_price  quantity  \
# 0      FAR_23  Faridabad  Female       Home Decor      677.74       2.0
# 1      GUW_44   Guwahati    Male     Frozen Foods      677.74       6.0
# 2      PAT_17      Patna  Female           Bakery       88.77       6.0
# 3      MEE_24     Meerut    Male           Snacks       77.40       3.0
# 4      THA_14      Thane    Male     Pet Supplies      751.38       4.0
#
#    total_price      gst payment_method  rating        date      time       day
# 0      1355.48   67.774       Mobikwik     2.6  2024-07-16  15:46:42       NaN
# 1      4066.44  203.322       Mobikwik     2.2  2024-06-15       NaN  Saturday
# 2       532.62   26.631           Cash     3.8  2024-12-14  14:27:15  Saturday
# 3       232.20   11.610        PhonePe     1.3  2025-03-16  22:10:38    Sunday
# 4      3005.52  150.276     Debit Card     3.0  2024-08-04  03:57:11    Sunday

# %%
df.isna().sum()
# Out:
# branch_code            0
# city                   0
# gender                 0
# product_category       0
# unit_price             0
# quantity               0
# total_price            0
# gst                    0
# payment_method         0
# rating                 0
# date                2993
# time                2991
# day                 2994
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (51458, 13)

# %%
df.isna().sum()
# Out:
# branch_code         0
# city                0
# gender              0
# product_category    0
# unit_price          0
# quantity            0
# total_price         0
# gst                 0
# payment_method      0
# rating              0
# date                0
# time                0
# day                 0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#       branch_code           city  gender   product_category  unit_price  \
# 1708       FAR_23      Faridabad    Male       Frozen Foods      690.73
# 1986       NAS_22         Nashik  Female   Sports Equipment      250.36
# 2238       VIS_16  Visakhapatnam    Male          Beverages      368.17
# 4059       MAD_42        Madurai    Male         Home Decor      787.93
# 4776       THA_14          Thane    Male  Health & Wellness      533.38
# ...           ...            ...     ...                ...         ...
# 59843      NOI_40          Noida    Male      Personal Care       55.15
# 59863      AMR_32       Amritsar    Male      Personal Care      691.71
# 59916      LUC_10        Lucknow    Male  Health & Wellness      629.72
# 59948      VIS_16  Visakhapatnam  Female         Stationery      256.25
# 59965      RAJ_25         Rajkot  Female   Sports Equipment      219.28
#
#        quantity  total_price       gst payment_method  rating        date  \
# ...

# %%
df.duplicated().sum()
# Out:
# 694

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# branch_code          object
# city                 object
# gender               object
# product_category     object
# unit_price          float64
# quantity            float64
# total_price         float64
# gst                 float64
# payment_method       object
# rating              float64
# date                 object
# time                 object
# day                  object
# dtype: object

# %%
df.head()
# Out:
#   branch_code      city  gender product_category  unit_price  quantity  \
# 2      PAT_17     Patna  Female           Bakery       88.77       6.0
# 3      MEE_24    Meerut    Male           Snacks       77.40       3.0
# 4      THA_14     Thane    Male     Pet Supplies      751.38       4.0
# 5      SRI_29  Srinagar  Female     Frozen Foods       42.30       2.0
# 6      SOL_46  Srinagar    Male    Personal Care      463.13       4.0
#
#    total_price      gst payment_method  rating        date      time       day
# 2       532.62   26.631           Cash     3.8  2024-12-14  14:27:15  Saturday
# 3       232.20   11.610        PhonePe     1.3  2025-03-16  22:10:38    Sunday
# 4      3005.52  150.276     Debit Card     3.0  2024-08-04  03:57:11    Sunday
# 5        84.60    4.230     Google Pay     1.4  2024-07-11  06:58:35  Thursday
# 6      1852.52   92.626     Debit Card     1.3  2025-06-17  14:42:34   Tuesday

# %%
temp = df.date + " " + df.time
df['datetime'] = pd.to_datetime(temp)

# %%
df.head()
# Out:
#   branch_code      city  gender product_category  unit_price  quantity  \
# 2      PAT_17     Patna  Female           Bakery       88.77       6.0
# 3      MEE_24    Meerut    Male           Snacks       77.40       3.0
# 4      THA_14     Thane    Male     Pet Supplies      751.38       4.0
# 5      SRI_29  Srinagar  Female     Frozen Foods       42.30       2.0
# 6      SOL_46  Srinagar    Male    Personal Care      463.13       4.0
#
#    total_price      gst payment_method  rating        date      time  \
# 2       532.62   26.631           Cash     3.8  2024-12-14  14:27:15
# 3       232.20   11.610        PhonePe     1.3  2025-03-16  22:10:38
# 4      3005.52  150.276     Debit Card     3.0  2024-08-04  03:57:11
# 5        84.60    4.230     Google Pay     1.4  2024-07-11  06:58:35
# 6      1852.52   92.626     Debit Card     1.3  2025-06-17  14:42:34
#
#         day            datetime
# 2  Saturday 2024-12-14 14:27:15
# 3    Sunday 2025-03-16 22:10:38
# ...

# %%
df.drop(['date','time'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   branch_code      city  gender product_category  unit_price  quantity  \
# 2      PAT_17     Patna  Female           Bakery       88.77       6.0
# 3      MEE_24    Meerut    Male           Snacks       77.40       3.0
# 4      THA_14     Thane    Male     Pet Supplies      751.38       4.0
# 5      SRI_29  Srinagar  Female     Frozen Foods       42.30       2.0
# 6      SOL_46  Srinagar    Male    Personal Care      463.13       4.0
#
#    total_price      gst payment_method  rating       day            datetime
# 2       532.62   26.631           Cash     3.8  Saturday 2024-12-14 14:27:15
# 3       232.20   11.610        PhonePe     1.3    Sunday 2025-03-16 22:10:38
# 4      3005.52  150.276     Debit Card     3.0    Sunday 2024-08-04 03:57:11
# 5        84.60    4.230     Google Pay     1.4  Thursday 2024-07-11 06:58:35
# 6      1852.52   92.626     Debit Card     1.3   Tuesday 2025-06-17 14:42:34

# %%
df.dtypes
# Out:
# branch_code                 object
# city                        object
# gender                      object
# product_category            object
# unit_price                 float64
# quantity                   float64
# total_price                float64
# gst                        float64
# payment_method              object
# rating                     float64
# day                         object
# datetime            datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#   branch_code      city  gender product_category  unit_price  quantity  \
# 2      PAT_17     Patna  Female           Bakery       88.77       6.0
# 3      MEE_24    Meerut    Male           Snacks       77.40       3.0
# 4      THA_14     Thane    Male     Pet Supplies      751.38       4.0
# 5      SRI_29  Srinagar  Female     Frozen Foods       42.30       2.0
# 6      SOL_46  Srinagar    Male    Personal Care      463.13       4.0
#
#    total_price      gst payment_method  rating       day            datetime
# 2       532.62   26.631           Cash     3.8  Saturday 2024-12-14 14:27:15
# 3       232.20   11.610        PhonePe     1.3    Sunday 2025-03-16 22:10:38
# 4      3005.52  150.276     Debit Card     3.0    Sunday 2024-08-04 03:57:11
# 5        84.60    4.230     Google Pay     1.4  Thursday 2024-07-11 06:58:35
# 6      1852.52   92.626     Debit Card     1.3   Tuesday 2025-06-17 14:42:34

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.gender = le.fit_transform(df.gender)

# %%
df.head()
# Out:
#   branch_code      city  gender product_category  unit_price  quantity  \
# 2      PAT_17     Patna       0           Bakery       88.77       6.0
# 3      MEE_24    Meerut       1           Snacks       77.40       3.0
# 4      THA_14     Thane       1     Pet Supplies      751.38       4.0
# 5      SRI_29  Srinagar       0     Frozen Foods       42.30       2.0
# 6      SOL_46  Srinagar       1    Personal Care      463.13       4.0
#
#    total_price      gst payment_method  rating       day            datetime
# 2       532.62   26.631           Cash     3.8  Saturday 2024-12-14 14:27:15
# 3       232.20   11.610        PhonePe     1.3    Sunday 2025-03-16 22:10:38
# 4      3005.52  150.276     Debit Card     3.0    Sunday 2024-08-04 03:57:11
# 5        84.60    4.230     Google Pay     1.4  Thursday 2024-07-11 06:58:35
# 6      1852.52   92.626     Debit Card     1.3   Tuesday 2025-06-17 14:42:34

# %%
df.payment_method.unique()
# Out:
# array(['Cash', 'PhonePe', 'Debit Card', 'Google Pay', 'Mobikwik',
#        'Credit Card', 'Paytm', 'Amazon Pay'], dtype=object)

# %%
le = LabelEncoder()
# df.payment_method = le.fit_transform(df.payment_method)

# %%
# df.payment_method.unique()

# %%
df.head()
# Out:
#   branch_code      city  gender product_category  unit_price  quantity  \
# 2      PAT_17     Patna       0           Bakery       88.77       6.0
# 3      MEE_24    Meerut       1           Snacks       77.40       3.0
# 4      THA_14     Thane       1     Pet Supplies      751.38       4.0
# 5      SRI_29  Srinagar       0     Frozen Foods       42.30       2.0
# 6      SOL_46  Srinagar       1    Personal Care      463.13       4.0
#
#    total_price      gst payment_method  rating       day            datetime
# 2       532.62   26.631           Cash     3.8  Saturday 2024-12-14 14:27:15
# 3       232.20   11.610        PhonePe     1.3    Sunday 2025-03-16 22:10:38
# 4      3005.52  150.276     Debit Card     3.0    Sunday 2024-08-04 03:57:11
# 5        84.60    4.230     Google Pay     1.4  Thursday 2024-07-11 06:58:35
# 6      1852.52   92.626     Debit Card     1.3   Tuesday 2025-06-17 14:42:34

# %%
df.product_category.unique()
# Out:
# array(['Bakery', 'Snacks', 'Pet Supplies', 'Frozen Foods',
#        'Personal Care', 'Baby Products', 'Fruits & Vegetables',
#        'Electronics', 'Household Items', 'Sports Equipment', 'Home Decor',
#        'Health & Wellness', 'Stationery', 'Clothing', 'Beverages',
#        'Dairy Products'], dtype=object)

# %%
df.payment_method
# Out:
# 2              Cash
# 3           PhonePe
# 4        Debit Card
# 5        Google Pay
# 6        Debit Card
#             ...
# 59995       PhonePe
# 59996       PhonePe
# 59997      Mobikwik
# 59998      Mobikwik
# 59999    Debit Card
# Name: payment_method, Length: 50764, dtype: object

# %%
df = pd.get_dummies(df, columns=['payment_method'], dtype=int)
df
# Out:
#       branch_code        city  gender     product_category  unit_price  \
# 2          PAT_17       Patna       0               Bakery       88.77
# 3          MEE_24      Meerut       1               Snacks       77.40
# 4          THA_14       Thane       1         Pet Supplies      751.38
# 5          SRI_29    Srinagar       0         Frozen Foods       42.30
# 6          SOL_46    Srinagar       1        Personal Care      463.13
# ...           ...         ...     ...                  ...         ...
# 59995      GUW_44    Guwahati       1         Frozen Foods      224.40
# 59996      MEE_24      Meerut       0         Pet Supplies      824.22
# 59997      SRI_29   Faridabad       0       Dairy Products      759.40
# 59998      ALL_34   Allahabad       0  Fruits & Vegetables      370.77
# 59999      CHA_45  Chandigarh       0  Fruits & Vegetables      134.36
#
#        quantity  total_price      gst  rating       day            datetime  \
# ...

# %%
import seaborn as sns
df1 = sns.load_dataset('titanic')
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
df1['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
oe.fit_transform(df1[['class']])
# Out:
# array([[2.],
#        [0.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [0.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [0.],
#        [0.],
#        [2.],
#        [0.],
#        [2.],
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['Third','Second','First']])
df1['class'] = oe.fit_transform(df1[['class']])

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S    0.0
# 1         1       1  female  38.0      1      0  71.2833        C    2.0
# 2         1       3  female  26.0      0      0   7.9250        S    0.0
# 3         1       1  female  35.0      1      0  53.1000        S    2.0
# 4         0       3    male  35.0      0      0   8.0500        S    0.0
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df2 = sns.load_dataset('tips')
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# !pip install category_encoders
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from category_encoders import TargetEncoder
te = TargetEncoder()
df2.day = te.fit_transform(df2.day, df2.total_bill)

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker        day    time  size
# 0       16.99  1.01  Female     No  21.404017  Dinner     2
# 1       10.34  1.66    Male     No  21.404017  Dinner     3
# 2       21.01  3.50    Male     No  21.404017  Dinner     3
# 3       23.68  3.31    Male     No  21.404017  Dinner     2
# 4       24.59  3.61  Female     No  21.404017  Dinner     4

# %%
df.head()
# Out:
#   branch_code      city  gender product_category  unit_price  quantity  \
# 2      PAT_17     Patna       0           Bakery       88.77       6.0
# 3      MEE_24    Meerut       1           Snacks       77.40       3.0
# 4      THA_14     Thane       1     Pet Supplies      751.38       4.0
# 5      SRI_29  Srinagar       0     Frozen Foods       42.30       2.0
# 6      SOL_46  Srinagar       1    Personal Care      463.13       4.0
#
#    total_price      gst  rating       day            datetime  \
# 2       532.62   26.631     3.8  Saturday 2024-12-14 14:27:15
# 3       232.20   11.610     1.3    Sunday 2025-03-16 22:10:38
# 4      3005.52  150.276     3.0    Sunday 2024-08-04 03:57:11
# 5        84.60    4.230     1.4  Thursday 2024-07-11 06:58:35
# 6      1852.52   92.626     1.3   Tuesday 2025-06-17 14:42:34
#
#    payment_method_Amazon Pay  payment_method_Cash  payment_method_Credit Card  \
# 2                          0                    1                           0
# ...

# %%
freq = df.city.value_counts()

# %%
df.city = df.city.map(freq)

# %%
df.head()
# Out:
#   branch_code  city  gender product_category  unit_price  quantity  \
# 2      PAT_17   986       0           Bakery       88.77       6.0
# 3      MEE_24  1002       1           Snacks       77.40       3.0
# 4      THA_14   997       1     Pet Supplies      751.38       4.0
# 5      SRI_29  3681       0     Frozen Foods       42.30       2.0
# 6      SOL_46  3681       1    Personal Care      463.13       4.0
#
#    total_price      gst  rating       day            datetime  \
# 2       532.62   26.631     3.8  Saturday 2024-12-14 14:27:15
# 3       232.20   11.610     1.3    Sunday 2025-03-16 22:10:38
# 4      3005.52  150.276     3.0    Sunday 2024-08-04 03:57:11
# 5        84.60    4.230     1.4  Thursday 2024-07-11 06:58:35
# 6      1852.52   92.626     1.3   Tuesday 2025-06-17 14:42:34
#
#    payment_method_Amazon Pay  payment_method_Cash  payment_method_Credit Card  \
# 2                          0                    1                           0
# ...

# %%
from category_encoders import BinaryEncoder
be = BinaryEncoder(cols=['product_category'])
df = be.fit_transform(df)

# %%
df.head()
# Out:
#   branch_code  city  gender  product_category_0  product_category_1  \
# 2      PAT_17   986       0                   0                   0
# 3      MEE_24  1002       1                   0                   0
# 4      THA_14   997       1                   0                   0
# 5      SRI_29  3681       0                   0                   0
# 6      SOL_46  3681       1                   0                   0
#
#    product_category_2  product_category_3  product_category_4  unit_price  \
# 2                   0                   0                   1       88.77
# 3                   0                   1                   0       77.40
# 4                   0                   1                   1      751.38
# 5                   1                   0                   0       42.30
# 6                   1                   0                   1      463.13
#
#    quantity  ...       day            datetime  payment_method_Amazon Pay  \
# ...

# %%
import pandas as pd

data = {
    "age" : [34,14,87,35,68,32],
    "salary" : [25000, 45000, 20000, 73000, 100000, 120000]
}
df = pd.DataFrame(data)
df
# Out:
#    age  salary
# 0   34   25000
# 1   14   45000
# 2   87   20000
# 3   35   73000
# 4   68  100000
# 5   32  120000

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
df['salary_ss'] = ss.fit_transform(df[['salary']])

# %%
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler()
df['salary_mms'] = mms.fit_transform(df[['salary']])

# %%
from sklearn.preprocessing import RobustScaler

rs = RobustScaler()
df['salary_rs'] = rs.fit_transform(df[['salary']])

# %%
df.head()
# Out:
#    age  salary  salary_ss  salary_mms  salary_rs
# 0   34   25000  -1.042164        0.05  -0.537549
# 1   14   45000  -0.505427        0.25  -0.221344
# 2   87   20000  -1.176348        0.00  -0.616601
# 3   35   73000   0.246004        0.53   0.221344
# 4   68  100000   0.970599        0.80   0.648221

# %%
salary1 = [12, 7, 14, 9, 6, 11, 8, 15, 10, 13,
5, 9, 12, 6, 14, 7, 11, 8, 13, 10,
15, 6, 9, 12, 7, 14, 8, 11, 10, 13,
5, 12, 9, 7, 14, 6, 11, 8, 15, 10,
13, 7, 12, 9, 6, 14, 8, 11, 10, 5,
15, 9, 7, 12, 6, 14, 8, 11, 10, 13,
5, 12, 9, 7, 14, 6, 11, 8, 15, 10,
13, 7, 12, 9, 6, 14, 8, 11, 10, 5,
15, 9, 7, 12, 6, 14, 8, 11, 10, 1000]

# %%
from scipy import stats
import numpy as  np

np.abs(stats.zscore(salary1))
# Out:
# array([0.08625985, 0.13441982, 0.06699587, 0.11515583, 0.14405181,
#        0.09589185, 0.12478783, 0.05736387, 0.10552384, 0.07662786,
#        0.15368381, 0.11515583, 0.08625985, 0.14405181, 0.06699587,
#        0.13441982, 0.09589185, 0.12478783, 0.07662786, 0.10552384,
#        0.05736387, 0.14405181, 0.11515583, 0.08625985, 0.13441982,
#        0.06699587, 0.12478783, 0.09589185, 0.10552384, 0.07662786,
#        0.15368381, 0.08625985, 0.11515583, 0.13441982, 0.06699587,
#        0.14405181, 0.09589185, 0.12478783, 0.05736387, 0.10552384,
#        0.07662786, 0.13441982, 0.08625985, 0.11515583, 0.14405181,
#        0.06699587, 0.12478783, 0.09589185, 0.10552384, 0.15368381,
#        0.05736387, 0.11515583, 0.13441982, 0.08625985, 0.14405181,
#        0.06699587, 0.12478783, 0.09589185, 0.10552384, 0.07662786,
#        0.15368381, 0.08625985, 0.11515583, 0.13441982, 0.06699587,
#        0.14405181, 0.09589185, 0.12478783, 0.05736387, 0.10552384,
# ...

# %%
import numpy as np
np.mean(salary1)
# Out:
# 20.955555555555556

# %%
salary2 = [12, 7, 14, 9, 6, 11, 8, 15, 10, 13, 5, 9, 12, 6, 14, 7, 11, 8, 13, 10,
15, 6, 9, 12, 7, 14, 8, 11, 10, 13, 5, 12, 9, 7, 14, 6, 11, 8, 15, 10,
13, 7, 12, 9, 6, 14, 8, 11, 10, 5, 15, 9, 7, 12, 6, 14, 8, 11, 10, 13,
5, 12, 9, 7, 14, 6, 11, 8, 15, 10, 13, 7, 12, 9, 6, 14, 8, 11, 10, 5,
15, 9, 7, 12, 6, 14, 8, 11, 10]

np.mean(salary2)
# Out:
# 9.955056179775282

# %%
import seaborn as sns

sns.boxplot(salary1)
# Out:
# <Axes: >

# %%
import seaborn as sns

sns.boxplot(salary2)
# Out:
# <Axes: >

# %%
df
# Out:
#    age  salary  salary_ss  salary_mms  salary_rs
# 0   34   25000  -1.042164        0.05  -0.537549
# 1   14   45000  -0.505427        0.25  -0.221344
# 2   87   20000  -1.176348        0.00  -0.616601
# 3   35   73000   0.246004        0.53   0.221344
# 4   68  100000   0.970599        0.80   0.648221
# 5   32  120000   1.507336        1.00   0.964427

# %%
df = pd.read_csv("loan_data.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.boxplot(df.LoanAmount)
# Out:
# <Axes: ylabel='LoanAmount'>

# %%
# !pip install scipy
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.dropna(inplace=True)

# %%
df.LoanAmount
# Out:
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
# 5      267.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 480, dtype: float64

# %%
from scipy import stats
z = np.abs(stats.zscore(df.LoanAmount))
df[z > 3]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 155  LP001536    Male     Yes         3+  Graduate            No
# 177  LP001610    Male     Yes         3+  Graduate            No
# 278  LP001907    Male     Yes          0  Graduate            No
# 308  LP001996    Male      No          0  Graduate            No
# 369  LP002191    Male     Yes          0  Graduate            No
# 487  LP002547    Male     Yes          1  Graduate            No
# 523  LP002693    Male     Yes          2  Graduate           Yes
# 525  LP002699    Male     Yes          2  Graduate           Yes
# 561  LP002813  Female     Yes          1  Graduate           Yes
# 604  LP002959  Female     Yes          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 155            39999                0.0       600.0             180.0
# 177             5516            11300.0       495.0             360.0
# ...

# %%
q3 = df.LoanAmount.quantile(0.75)
q1 = df.LoanAmount.quantile(0.25)

IQR = q3 - q1
IQR
# Out:
# 70.0

# %%
lower = q1 - 1.5*IQR
lower
# Out:
# -5.0

# %%
upper = q3 + 1.5*IQR
upper
# Out:
# 275.0

# %%
outliers = df[(df.LoanAmount < lower) | (df.LoanAmount > upper)]

# %%
outliers
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 9    LP001020    Male     Yes          1      Graduate            No
# 21   LP001046    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 67   LP001233    Male     Yes          1      Graduate            No
# 135  LP001488    Male     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 233  LP001776  Female      No          0      Graduate            No
# 253  LP001843    Male     Yes          1  Not Graduate            No
# 258  LP001859    Male     Yes          0      Graduate            No
# 278  LP001907    Male     Yes          0      Graduate            No
# 308  LP001996    Male      No          0      Graduate            No
# ...

# %%
df1 = df[(df.LoanAmount >= lower) & (df.LoanAmount <= upper)]

# %%
df1.LoanAmount.max()
# Out:
# 275.0

# %%
df1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# ...

# %%
sns.boxplot(df1.LoanAmount)
# Out:
# <Axes: ylabel='LoanAmount'>

# %%
sns.boxplot(df.LoanAmount)
# Out:
# <Axes: ylabel='LoanAmount'>

# %%
sns.histplot(df.LoanAmount, kde=True)
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Count'>

# %%
df['LoanAmount_log'] = np.log1p(df.LoanAmount)

# %%
sns.histplot(df.LoanAmount_log, kde=True)
# Out:
# <Axes: xlabel='LoanAmount_log', ylabel='Count'>

# %%
df.dropna(inplace=True)

# %%
from scipy import stats
df['LoanAmount_boxcox'], _ = stats.boxcox(df.LoanAmount)

# %%
sns.histplot(df.LoanAmount_boxcox, kde=True)
# Out:
# <Axes: xlabel='LoanAmount_boxcox', ylabel='Count'>

# %%
df['LoanAmount_sqrt'] = np.sqrt(df.LoanAmount)

# %%
df['LoanAmount_power'] = np.power(df.LoanAmount, 1/4)

# %%
sns.histplot(df.LoanAmount_power, kde=True)
# Out:
# <Axes: xlabel='LoanAmount_power', ylabel='Count'>

# %%
sns.histplot(df.LoanAmount_sqrt, kde=True)
# Out:
# <Axes: xlabel='LoanAmount_sqrt', ylabel='Count'>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status  LoanAmount_log  \
# 1             1.0         Rural           N        4.859812
# ...

# %%
df = pd.read_csv("Big_Bazaar.csv")
df.head()
# Out:
#   branch_code       city  gender product_category  unit_price  quantity  \
# 0      FAR_23  Faridabad  Female       Home Decor         NaN       2.0
# 1      GUW_44   Guwahati    Male     Frozen Foods         NaN       6.0
# 2      PAT_17      Patna  Female           Bakery       88.77       NaN
# 3      MEE_24     Meerut    Male           Snacks       77.40       3.0
# 4      THA_14      Thane    Male     Pet Supplies      751.38       4.0
#
#    total_price     gst payment_method  rating        date      time       day
# 0      1294.08  232.93            NaN     2.6  2024-07-16  15:46:42       NaN
# 1      5804.46     NaN       Mobikwik     2.2  2024-06-15       NaN  Saturday
# 2       266.31   47.94           Cash     3.8  2024-12-14  14:27:15  Saturday
# 3       232.20   41.80        PhonePe     1.3  2025-03-16  22:10:38    Sunday
# 4      3005.52  540.99     Debit Card     3.0  2024-08-04  03:57:11    Sunday

# %%
df.dropna(inplace=True)

# %%
temp = df.date + " " + df.time
df['datetime'] = pd.to_datetime(temp)
df.head()
# Out:
#   branch_code      city  gender product_category  unit_price  quantity  \
# 3      MEE_24    Meerut    Male           Snacks       77.40       3.0
# 4      THA_14     Thane    Male     Pet Supplies      751.38       4.0
# 7      LUD_20  Ludhiana    Male           Bakery       50.47       6.0
# 8      NOI_40     Noida  Female    Baby Products      333.42       8.0
# 9      JAI_08    Jaipur    Male           Snacks      567.52       4.0
#
#    total_price     gst payment_method  rating        date      time      day  \
# 3       232.20   41.80        PhonePe     1.3  2025-03-16  22:10:38   Sunday
# 4      3005.52  540.99     Debit Card     3.0  2024-08-04  03:57:11   Sunday
# 7       302.82   54.51       Mobikwik     2.2  2024-02-26  23:31:42   Monday
# 8      2667.36  480.12     Debit Card     3.6  2023-12-12  06:21:42  Tuesday
# 9      2270.08  408.61     Google Pay     1.7  2024-08-23  13:15:52   Friday
#
#              datetime
# 3 2025-03-16 22:10:38
# 4 2024-08-04 03:57:11
# ...

# %%
df.drop(['date', 'time'], axis=1, inplace=True)

# %%
df.datetime
# Out:
# 3       2025-03-16 22:10:38
# 4       2024-08-04 03:57:11
# 7       2024-02-26 23:31:42
# 8       2023-12-12 06:21:42
# 9       2024-08-23 13:15:52
#                 ...
# 59994   2024-09-27 07:11:01
# 59995   2024-12-15 23:26:24
# 59996   2025-04-21 07:40:02
# 59998   2024-09-10 16:57:06
# 59999   2024-10-13 08:44:45
# Name: datetime, Length: 30663, dtype: datetime64[ns]

# %%
df['year'] = df.datetime.dt.year

# %%
df['month'] = df.datetime.dt.month

# %%
df.datetime.dt.day
# Out:
# 3        16
# 4         4
# 7        26
# 8        12
# 9        23
#          ..
# 59994    27
# 59995    15
# 59996    21
# 59998    10
# 59999    13
# Name: datetime, Length: 30663, dtype: int32

# %%
df.datetime.dt.second
# Out:
# 3        38
# 4        11
# 7        42
# 8        42
# 9        52
#          ..
# 59994     1
# 59995    24
# 59996     2
# 59998     6
# 59999    45
# Name: datetime, Length: 30663, dtype: int32

# %%
df.datetime.dt.day_of_week
# Out:
# 3        6
# 4        6
# 7        0
# 8        1
# 9        4
#         ..
# 59994    4
# 59995    6
# 59996    0
# 59998    1
# 59999    6
# Name: datetime, Length: 30663, dtype: int32

# %%
df.head()
# Out:
#   branch_code      city  gender product_category  unit_price  quantity  \
# 3      MEE_24    Meerut    Male           Snacks       77.40       3.0
# 4      THA_14     Thane    Male     Pet Supplies      751.38       4.0
# 7      LUD_20  Ludhiana    Male           Bakery       50.47       6.0
# 8      NOI_40     Noida  Female    Baby Products      333.42       8.0
# 9      JAI_08    Jaipur    Male           Snacks      567.52       4.0
#
#    total_price     gst payment_method  rating      day            datetime  \
# 3       232.20   41.80        PhonePe     1.3   Sunday 2025-03-16 22:10:38
# 4      3005.52  540.99     Debit Card     3.0   Sunday 2024-08-04 03:57:11
# 7       302.82   54.51       Mobikwik     2.2   Monday 2024-02-26 23:31:42
# 8      2667.36  480.12     Debit Card     3.6  Tuesday 2023-12-12 06:21:42
# 9      2270.08  408.61     Google Pay     1.7   Friday 2024-08-23 13:15:52
#
#    year  month
# 3  2025      3
# 4  2024      8
# 7  2024      2
# 8  2023     12
# ...

# %%
df = pd.read_csv("loan_data.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.ApplicantIncome.min()
# Out:
# 150

# %%
df.ApplicantIncome.max()
# Out:
# 81000

# %%
np.linspace(150, 81000, 4)
# Out:
# array([  150., 27100., 54050., 81000.])

# %%
df['ApplicantIncome_label'] = pd.cut(df.ApplicantIncome, 
       bins=[150, 27100, 54050, 81000],
       labels=['Low', 'Medium', 'High'])
# Out:
# 0      Low
# 1      Low
# 2      Low
# 3      Low
# 4      Low
#       ...
# 609    Low
# 610    Low
# 611    Low
# 612    Low
# 613    Low
# Name: ApplicantIncome, Length: 614, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']
