# %%
import pandas as pd

data = {
    "Name":["Rahul", "Alena", "Ravi", "Neha"],
    "Age" : [21,24,23,20],
    "City" : ['Delhi', 'Mumbai', 'Pune', 'Bangalore'],
    "Marks" :[90, 89, 70, 79]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age       City  Marks
# 0  Rahul   21      Delhi     90
# 1  Alena   24     Mumbai     89
# 2   Ravi   23       Pune     70
# 3   Neha   20  Bangalore     79

# %%
df.head(2)
# Out:
#     Name  Age    City  Marks
# 0  Rahul   21   Delhi     90
# 1  Alena   24  Mumbai     89

# %%
df.head(3)
# Out:
#     Name  Age    City  Marks
# 0  Rahul   21   Delhi     90
# 1  Alena   24  Mumbai     89
# 2   Ravi   23    Pune     70

# %%
df.tail(1)
# Out:
#    Name  Age       City  Marks
# 3  Neha   20  Bangalore     79

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
#  3   Marks   4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df.describe()
# Out:
#              Age      Marks
# count   4.000000   4.000000
# mean   22.000000  82.000000
# std     1.825742   9.416298
# min    20.000000  70.000000
# 25%    20.750000  76.750000
# 50%    22.000000  84.000000
# 75%    23.250000  89.250000
# max    24.000000  90.000000

# %%
df
# Out:
#     Name  Age       City  Marks
# 0  Rahul   21      Delhi     90
# 1  Alena   24     Mumbai     89
# 2   Ravi   23       Pune     70
# 3   Neha   20  Bangalore     79

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Marks'], dtype='object')

# %%
df
# Out:
#     Name  Age       City  Marks
# 0  Rahul   21      Delhi     90
# 1  Alena   24     Mumbai     89
# 2   Ravi   23       Pune     70
# 3   Neha   20  Bangalore     79

# %%
df.shape
# Out:
# (4, 4)

# %%
df
# Out:
#     Name  Age       City  Marks
# 0  Rahul   21      Delhi     90
# 1  Alena   24     Mumbai     89
# 2   Ravi   23       Pune     70
# 3   Neha   20  Bangalore     79

# %%
# df.Name
df['Name']
# Out:
# 0    Rahul
# 1    Alena
# 2     Ravi
# 3     Neha
# Name: Name, dtype: object

# %%
df.Age
# Out:
# 0    21
# 1    24
# 2    23
# 3    20
# Name: Age, dtype: int64

# %%
df.City
# Out:
# 0        Delhi
# 1       Mumbai
# 2         Pune
# 3    Bangalore
# Name: City, dtype: object

# %%
df[['Name', 'Marks']]
# Out:
#     Name  Marks
# 0  Rahul     90
# 1  Alena     89
# 2   Ravi     70
# 3   Neha     79

# %%
import pandas as pd
df = pd.read_csv("rapido_data.csv")
df
# Out:
#          services        date      time ride_status  \
# 0            bike  2024-06-23  19:18:20   completed
# 1       bike lite  2024-07-06   2:42:20   completed
# 2          parcel  2024-07-19  17:55:20   completed
# 3            bike  2024-07-20   5:38:20   cancelled
# 4     cab economy  2024-07-12  19:36:20   completed
# ...           ...         ...       ...         ...
# 9995         auto  2024-07-01   9:57:20   cancelled
# 9996   auto share  2024-07-10   2:47:20   completed
# 9997   auto share  2024-07-06  23:56:20   cancelled
# 9998  cab premium  2024-07-23   6:10:20   cancelled
# 9999  cab economy  2024-07-20   7:42:20   completed
#
#                               source                destination  duration  \
# 0             Banashankari 7th Stage              Richmond Road        99
# 1                  Indiranagar North              Sahakar Nagar        48
# 2        MG Road Mahatma Gandhi Road           Whitefield South       112
# ...

# %%
df
# Out:
#          services        date      time ride_status  \
# 0            bike  2024-06-23  19:18:20   completed
# 1       bike lite  2024-07-06   2:42:20   completed
# 2          parcel  2024-07-19  17:55:20   completed
# 3            bike  2024-07-20   5:38:20   cancelled
# 4     cab economy  2024-07-12  19:36:20   completed
# ...           ...         ...       ...         ...
# 9995         auto  2024-07-01   9:57:20   cancelled
# 9996   auto share  2024-07-10   2:47:20   completed
# 9997   auto share  2024-07-06  23:56:20   cancelled
# 9998  cab premium  2024-07-23   6:10:20   cancelled
# 9999  cab economy  2024-07-20   7:42:20   completed
#
#                               source                destination  duration  \
# 0             Banashankari 7th Stage              Richmond Road        99
# 1                  Indiranagar North              Sahakar Nagar        48
# 2        MG Road Mahatma Gandhi Road           Whitefield South       112
# ...

# %%
df.head(7)
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
# 5    bike lite  2024-07-07  20:01:20   cancelled        Indiranagar 7th Stage
# 6    bike lite  2024-07-01  22:54:20   completed             Kadubeesanahalli
#
#               destination  duration             ride_id  distance  \
# 0           Richmond Road        99  RD8660319589404637     18.68
# 1           Sahakar Nagar        48  RD4484661533610497     42.55
# 2        Whitefield South       112  RD1526455182706880      5.85
# 3   Rajajinagar 7th Block        45  RD7207154929912440     16.64
# ...

# %%
df.head(3)
# Out:
#     services        date      time ride_status                       source  \
# 0       bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1  bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2     parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
#
#         destination  duration             ride_id  distance  ride_charge  \
# 0     Richmond Road        99  RD8660319589404637     18.68        93.09
# 1     Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2  Whitefield South       112  RD1526455182706880      5.85       247.90
#
#    misc_charge  total_fare payment_method
# 0         2.32       95.41     Amazon Pay
# 1        11.68      432.45        QR scan
# 2        27.45      275.35           GPay

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df.tail()
# Out:
#          services        date      time ride_status  \
# 9995         auto  2024-07-01   9:57:20   cancelled
# 9996   auto share  2024-07-10   2:47:20   completed
# 9997   auto share  2024-07-06  23:56:20   cancelled
# 9998  cab premium  2024-07-23   6:10:20   cancelled
# 9999  cab economy  2024-07-20   7:42:20   completed
#
#                               source                destination  duration  \
# 9995  Brigade Road Mota Royal Arcade                Neelasandra       120
# 9996                     Frazer Town        MG Road Cubbon Park        71
# 9997      Brigade Road Church Street  HSR Layout Sector 5 North        71
# 9998           Rajajinagar 2nd Block         HSR Layout Central        26
# 9999                    Hebbal North       HSR Layout Sector 10        88
#
#                  ride_id  distance  ride_charge  misc_charge  total_fare  \
# 9995  RD8489738606219832     10.70          NaN          NaN         NaN
# ...

# %%
df.tail(10)
# Out:
#          services        date      time ride_status  \
# 9990   auto share  2024-07-18   1:30:20   completed
# 9991  cab premium  2024-07-23  18:30:20   cancelled
# 9992   auto share  2024-06-23  11:27:20   cancelled
# 9993  cab economy  2024-07-17  14:25:20   completed
# 9994  cab premium  2024-07-17   7:52:20   cancelled
# 9995         auto  2024-07-01   9:57:20   cancelled
# 9996   auto share  2024-07-10   2:47:20   completed
# 9997   auto share  2024-07-06  23:56:20   cancelled
# 9998  cab premium  2024-07-23   6:10:20   cancelled
# 9999  cab economy  2024-07-20   7:42:20   completed
#
#                               source                  destination  duration  \
# 9990           Koramangala 9th Block  Brigade Road Residency Road        67
# 9991                Koramangala West           Yelahanka Old Town        94
# 9992            Brigade Road Central                   Ganganagar        94
# 9993       HSR Layout Sector 5 South                  Nandi Hills        57
# ...

# %%
df.tail(3)
# Out:
#          services        date      time ride_status  \
# 9997   auto share  2024-07-06  23:56:20   cancelled
# 9998  cab premium  2024-07-23   6:10:20   cancelled
# 9999  cab economy  2024-07-20   7:42:20   completed
#
#                           source                destination  duration  \
# 9997  Brigade Road Church Street  HSR Layout Sector 5 North        71
# 9998       Rajajinagar 2nd Block         HSR Layout Central        26
# 9999                Hebbal North       HSR Layout Sector 10        88
#
#                  ride_id  distance  ride_charge  misc_charge  total_fare  \
# 9997  RD9632805396891647      2.41          NaN          NaN         NaN
# 9998  RD1640451808051338     45.75          NaN          NaN         NaN
# 9999  RD3004823158884110     19.86       565.39        46.42      611.81
#
#      payment_method
# 9997            NaN
# 9998            NaN
# 9999          Paytm

# %%
df.sample(10)
# Out:
#          services        date      time ride_status  \
# 1277         auto  2024-07-15   3:52:20   cancelled
# 7702       parcel  2024-07-05  19:44:20   cancelled
# 9096   auto share  2024-07-14  19:21:20   completed
# 7378         auto  2024-06-27  15:30:20   completed
# 2721         auto  2024-07-14  21:48:20   completed
# 6168    bike lite  2024-06-24   3:29:20   cancelled
# 7280         bike  2024-07-04   0:13:20   cancelled
# 5224  cab economy  2024-07-17   2:28:20   cancelled
# 5536       parcel  2024-07-06  21:16:20   completed
# 8678         bike  2024-07-03  14:46:20   cancelled
#
#                           source                destination  duration  \
# 1277                      Peenya      Rajajinagar 6th Block       101
# 7702           JP Nagar Phase 10            Victoria Layout        51
# 9096  HSR Layout Sector 10 North                    Kengeri       114
# 7378      Banashankari 3rd Stage   Jayanagar 9th Block East        31
# ...

# %%
df.sample(5)
# Out:
#          services        date      time ride_status                  source  \
# 7714         bike  2024-07-19  19:36:20   completed         HSR Layout East
# 5361         bike  2024-07-11  15:02:20   completed   Indiranagar 9th Stage
# 6517    bike lite  2024-07-23   3:27:20   cancelled  Banashankari 6th Stage
# 7706  cab economy  2024-07-01  10:14:20   cancelled              Cooke Town
# 5211         bike  2024-07-07   5:37:20   cancelled        Kadubeesanahalli
#
#                     destination  duration             ride_id  distance  \
# 7714     Banashankari 5th Stage       120  RD7570932404747697     46.81
# 5361      Rajajinagar 5th Block       100  RD2321429254485161     13.41
# 6517             St. Marks Road        63  RD2217353852821126     28.03
# 7706  Jayanagar 10th Block East        24  RD6786866022817296     12.72
# 5211      Rajajinagar 4th Block        40  RD2116237001172330     36.02
#
#       ride_charge  misc_charge  total_fare payment_method
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   services        10000 non-null  object
#  1   date            10000 non-null  object
#  2   time            10000 non-null  object
#  3   ride_status     10000 non-null  object
#  4   source          10000 non-null  object
#  5   destination     10000 non-null  object
#  6   duration        10000 non-null  int64
#  7   ride_id         10000 non-null  object
#  8   distance        10000 non-null  float64
#  9   ride_charge     4611 non-null   float64
#  10  misc_charge     4611 non-null   float64
#  11  total_fare      4611 non-null   float64
#  12  payment_method  4611 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1015.8+ KB

# %%
df.columns
# Out:
# Index(['services', 'date', 'time', 'ride_status', 'source', 'destination',
#        'duration', 'ride_id', 'distance', 'ride_charge', 'misc_charge',
#        'total_fare', 'payment_method'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.dtypes
# Out:
# services           object
# date               object
# time               object
# ride_status        object
# source             object
# destination        object
# duration            int64
# ride_id            object
# distance          float64
# ride_charge       float64
# misc_charge       float64
# total_fare        float64
# payment_method     object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
# df.services	
df['services']
# Out:
# 0              bike
# 1         bike lite
# 2            parcel
# 3              bike
# 4       cab economy
#            ...
# 9995           auto
# 9996     auto share
# 9997     auto share
# 9998    cab premium
# 9999    cab economy
# Name: services, Length: 10000, dtype: object

# %%
df.source
# Out:
# 0               Banashankari 7th Stage
# 1                    Indiranagar North
# 2          MG Road Mahatma Gandhi Road
# 3                             JP Nagar
# 4                     Whitefield North
#                      ...
# 9995    Brigade Road Mota Royal Arcade
# 9996                       Frazer Town
# 9997        Brigade Road Church Street
# 9998             Rajajinagar 2nd Block
# 9999                      Hebbal North
# Name: source, Length: 10000, dtype: object

# %%
df[['source', 'destination', 'total_fare']]
# Out:
#                               source                destination  total_fare
# 0             Banashankari 7th Stage              Richmond Road       95.41
# 1                  Indiranagar North              Sahakar Nagar      432.45
# 2        MG Road Mahatma Gandhi Road           Whitefield South      275.35
# 3                           JP Nagar      Rajajinagar 7th Block         NaN
# 4                   Whitefield North      Brigade Road Eva Mall      807.70
# ...                              ...                        ...         ...
# 9995  Brigade Road Mota Royal Arcade                Neelasandra         NaN
# 9996                     Frazer Town        MG Road Cubbon Park      147.96
# 9997      Brigade Road Church Street  HSR Layout Sector 5 North         NaN
# 9998           Rajajinagar 2nd Block         HSR Layout Central         NaN
# 9999                    Hebbal North       HSR Layout Sector 10      611.81
#
# [10000 rows x 3 columns]

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df.iloc[3]
# Out:
# services                           bike
# date                         2024-07-20
# time                            5:38:20
# ride_status                   cancelled
# source                         JP Nagar
# destination       Rajajinagar 7th Block
# duration                             45
# ride_id              RD7207154929912440
# distance                          16.64
# ride_charge                         NaN
# misc_charge                         NaN
# total_fare                          NaN
# payment_method                      NaN
# Name: 3, dtype: object

# %%
df.iloc[3000]
# Out:
# services                    cab economy
# date                         2024-06-28
# time                           19:18:20
# ride_status                   cancelled
# source                    JP Nagar West
# destination       Indiranagar 2nd Stage
# duration                             38
# ride_id              RD9561801262501650
# distance                          20.44
# ride_charge                         NaN
# misc_charge                         NaN
# total_fare                          NaN
# payment_method                      NaN
# Name: 3000, dtype: object

# %%
df.loc[3000]
# Out:
# services                    cab economy
# date                         2024-06-28
# time                           19:18:20
# ride_status                   cancelled
# source                    JP Nagar West
# destination       Indiranagar 2nd Stage
# duration                             38
# ride_id              RD9561801262501650
# distance                          20.44
# ride_charge                         NaN
# misc_charge                         NaN
# total_fare                          NaN
# payment_method                      NaN
# Name: 3000, dtype: object

# %%
import pandas as pd

# Create data
data = {
    "Name": ["Rahul", "Anita", "Vikram", "Sneha"],
    "City": ["Delhi", "Mumbai", "Chennai", "Hyderabad"],
    "Age": [25, 30, 28, 22]
}

# Create DataFrame with custom index
df1 = pd.DataFrame(data, index=[101, 102, 103, 104])

df1
# Out:
#        Name       City  Age
# 101   Rahul      Delhi   25
# 102   Anita     Mumbai   30
# 103  Vikram    Chennai   28
# 104   Sneha  Hyderabad   22

# %%
df1.loc[103]
# Out:
# Name     Vikram
# City    Chennai
# Age          28
# Name: 103, dtype: object

# %%
df1.iloc[2]
# Out:
# Name     Vikram
# City    Chennai
# Age          28
# Name: 103, dtype: object

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df[df.duration > 100]
# Out:
#          services        date      time ride_status  \
# 2          parcel  2024-07-19  17:55:20   completed
# 10           auto  2024-07-07  20:38:20   completed
# 11           bike  2024-07-11  15:12:20   cancelled
# 17     auto share  2024-07-22  10:59:20   cancelled
# 27    cab economy  2024-07-12  18:09:20   cancelled
# ...           ...         ...       ...         ...
# 9977   auto share  2024-07-17   6:01:20   cancelled
# 9981         bike  2024-07-08  18:49:20   cancelled
# 9988         auto  2024-06-29   7:41:20   completed
# 9994  cab premium  2024-07-17   7:52:20   cancelled
# 9995         auto  2024-07-01   9:57:20   cancelled
#
#                               source                  destination  duration  \
# 2        MG Road Mahatma Gandhi Road             Whitefield South       112
# 10          Jayanagar 6th Block East          HSR Layout Sector 5       113
# 11             Rajajinagar 3rd Block     Jayanagar 2nd Block East       106
# ...

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df[df.services == "bike"]
# Out:
#      services        date      time ride_status                       source  \
# 0        bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 3        bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 11       bike  2024-07-11  15:12:20   cancelled        Rajajinagar 3rd Block
# 13       bike  2024-06-29  22:31:20   cancelled      Whitefield Mahadevapura
# 22       bike  2024-07-23  15:21:20   cancelled                  Queens Road
# ...       ...         ...       ...         ...                          ...
# 9972     bike  2024-07-12  10:50:20   completed                  Ashok Nagar
# 9975     bike  2024-07-11  19:58:20   completed       Brigade Road Mayo Hall
# 9981     bike  2024-07-08  18:49:20   cancelled          Whitefield ECC Road
# 9984     bike  2024-07-18   1:50:20   cancelled  Brigade Road Residency Road
# 9985     bike  2024-06-27  21:34:20   completed             Kadubeesanahalli
#
# ...

# %%
c1 = df.total_fare > 400
c2 = df.payment_method == "Amazon Pay"
df[c1 & c2]

# %%
df[(df.total_fare > 400) & (df.payment_method == "Amazon Pay")]
# Out:
#          services        date      time ride_status                 source  \
# 6       bike lite  2024-07-01  22:54:20   completed       Kadubeesanahalli
# 7            auto  2024-06-24  18:26:20   completed    Jayanagar 8th Block
# 18           auto  2024-07-06   1:43:20   completed      Indiranagar North
# 28    cab premium  2024-07-12   2:43:20   completed         Vidyaranyapura
# 31           bike  2024-07-09   1:18:20   completed     Hebbal Dasarahalli
# ...           ...         ...       ...         ...                    ...
# 9883   auto share  2024-07-11  15:01:20   completed  Electronic City North
# 9888   auto share  2024-07-10   1:23:20   completed            Rajajinagar
# 9898  cab economy  2024-07-21  21:51:20   completed         Sadashivanagar
# 9914       parcel  2024-06-25   8:09:20   completed           Lavelle Road
# 9988         auto  2024-06-29   7:41:20   completed          Sarjapur Road
#
# ...

# %%
df.sort_values(by="duration", ascending=False)
# Out:
#          services        date      time ride_status  \
# 8606  cab economy  2024-07-18  11:14:20   cancelled
# 9166  cab economy  2024-07-20  15:12:20   completed
# 5896  cab premium  2024-07-19   6:34:20   completed
# 2025  cab premium  2024-06-24  20:32:20   cancelled
# 2621  cab premium  2024-06-23  23:53:20   completed
# ...           ...         ...       ...         ...
# 1472       parcel  2024-07-04  14:11:20   cancelled
# 6244         bike  2024-07-01  21:15:20   cancelled
# 1447   auto share  2024-06-26  14:45:20   completed
# 7100         bike  2024-06-30   4:31:20   cancelled
# 1177    bike lite  2024-06-27   5:10:20   completed
#
#                               source               destination  duration  \
# 8606       HSR Layout Sector 3 South  Jayanagar 7th Block East       120
# 9166           Indiranagar 1st Stage              Hebbal North       120
# 5896            Brigade Road Central        Hebbal Dasarahalli       120
# ...

# %%
df.sort_values(by="duration")
# Out:
#          services        date      time ride_status  \
# 6244         bike  2024-07-01  21:15:20   cancelled
# 7013   auto share  2024-06-28  23:15:20   completed
# 703        parcel  2024-07-20  10:28:20   cancelled
# 8002         auto  2024-06-26  14:12:20   completed
# 3378         auto  2024-07-11  15:53:20   completed
# ...           ...         ...       ...         ...
# 8399         bike  2024-07-22   2:04:20   completed
# 685        parcel  2024-07-19  10:49:20   completed
# 4399  cab economy  2024-07-04  19:34:20   cancelled
# 661          bike  2024-06-24   7:17:20   cancelled
# 8093         auto  2024-07-07  12:51:20   cancelled
#
#                          source               destination  duration  \
# 6244      Koramangala 3rd Block    Banashankari 9th Stage         5
# 7013           JP Nagar Phase 7    Banashankari 4th Stage         5
# 703               MG Road South             Infantry Road         5
# ...

# %%
df.shape
# Out:
# (10000, 13)

# %%
df['discount'] = 10

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df['discount_amt'] = df.total_fare * 0.1

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df.sample(10)
# Out:
#          services        date      time ride_status                   source  \
# 683     bike lite  2024-07-01  14:05:20   cancelled       JP Nagar 8th Phase
# 4335         bike  2024-07-19  12:41:20   completed      HSR Layout Sector 4
# 703        parcel  2024-07-20  10:28:20   cancelled            MG Road South
# 2734       parcel  2024-06-29  17:03:20   cancelled      Koramangala Central
# 1897         bike  2024-06-25   4:21:20   cancelled       Malleshwaram North
# 3346       parcel  2024-07-07   0:49:20   completed      Jayanagar 2nd Block
# 7881  cab economy  2024-07-11   4:53:20   completed         JP Nagar Phase 3
# 8594  cab premium  2024-07-09  11:47:20   cancelled  Malleshwaram 10th Block
# 1332         bike  2024-06-24   1:16:20   completed         JP Nagar Phase 3
# 5437         auto  2024-06-24   8:10:20   cancelled     Jayanagar 10th Block
#
#                     destination  duration             ride_id  distance  \
# ...

# %%
# df.isnull().sum()
df.isna().sum()
# Out:
# services             0
# date                 0
# time                 0
# ride_status          0
# source               0
# destination          0
# duration             0
# ride_id              0
# distance             0
# ride_charge       5389
# misc_charge       5389
# total_fare        5389
# payment_method    5389
# discount             0
# discount_amt      5389
# dtype: int64

# %%
df.head(7)
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
# 5    bike lite  2024-07-07  20:01:20   cancelled        Indiranagar 7th Stage
# 6    bike lite  2024-07-01  22:54:20   completed             Kadubeesanahalli
#
#               destination  duration             ride_id  distance  \
# 0           Richmond Road        99  RD8660319589404637     18.68
# 1           Sahakar Nagar        48  RD4484661533610497     42.55
# 2        Whitefield South       112  RD1526455182706880      5.85
# 3   Rajajinagar 7th Block        45  RD7207154929912440     16.64
# ...

# %%
df.total_fare.min()
# Out:
# 18.81

# %%
df.total_fare.max()
# Out:
# 1044.29

# %%
df.total_fare.mean()
# Out:
# 530.5047408371286

# %%
df.total_fare.median()
# Out:
# 528.9

# %%
df.total_fare.sum()
# Out:
# 2446157.36

# %%
df.payment_method.mode()
# Out:
# 0    QR scan
# Name: payment_method, dtype: object

# %%
df.payment_method.unique()
# Out:
# array(['Amazon Pay', 'QR scan', 'GPay', nan, 'Paytm', 'Cash', 'phonePy'],
#       dtype=object)

# %%
df.payment_method.value_counts()
# Out:
# payment_method
# QR scan       797
# Paytm         790
# Amazon Pay    772
# phonePy       760
# Cash          755
# GPay          737
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df.services.value_counts()
# Out:
# services
# auto           1479
# auto share     1473
# cab premium    1448
# bike lite      1424
# cab economy    1406
# bike           1388
# parcel         1382
# Name: count, dtype: int64

# %%
df[['services','total_fare']]
# Out:
#          services  total_fare
# 0            bike       95.41
# 1       bike lite      432.45
# 2          parcel      275.35
# 3            bike         NaN
# 4     cab economy      807.70
# ...           ...         ...
# 9995         auto         NaN
# 9996   auto share      147.96
# 9997   auto share         NaN
# 9998  cab premium         NaN
# 9999  cab economy      611.81
#
# [10000 rows x 2 columns]

# %%
df.groupby('services')['total_fare'].sum()
# Out:
# services
# auto           391063.19
# auto share     346887.26
# bike           321782.00
# bike lite      354782.15
# cab economy    334850.51
# cab premium    345342.95
# parcel         351449.30
# Name: total_fare, dtype: float64

# %%
import pandas as pd

data = {
    "City": ["Hyderabad", "Hyderabad", "Bangalore", "Bangalore", "Chennai", "Chennai"],
    "Product": ["Laptop", "Mobile", "Laptop", "Mobile", "Laptop", "Mobile"],
    "Sales": [50000, 20000, 45000, 25000, 40000, 15000],
    "Quantity": [5, 10, 4, 12, 3, 8]
}

df2 = pd.DataFrame(data)

df2
# Out:
#         City Product  Sales  Quantity
# 0  Hyderabad  Laptop  50000         5
# 1  Hyderabad  Mobile  20000        10
# 2  Bangalore  Laptop  45000         4
# 3  Bangalore  Mobile  25000        12
# 4    Chennai  Laptop  40000         3
# 5    Chennai  Mobile  15000         8

# %%
df2.groupby('City')['Sales'].sum()
# Out:
# City
# Bangalore    70000
# Chennai      55000
# Hyderabad    70000
# Name: Sales, dtype: int64

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...
