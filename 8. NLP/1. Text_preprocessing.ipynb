# %%
text = "I Love Machine Leaning & AI!!!. it is best thing to learn in 2026"

# %%
text = text.lower()

# %%
import re

#re.sub(pattern, replacement, text)
# text = re.sub(r'[^a-z0-9\s]', '', text)
text = re.sub(r'[^a-z\s]', '', text)
text
# Out:
# 'i love machine leaning  ai it is best thing to learn in '

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\visha\appdata\local\programs\python\python311\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\visha\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\visha\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\visha\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\visha\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\visha\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
text
# Out:
# 'i love machine leaning  ai it is best thing to learn in '

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\visha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\visha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
text = word_tokenize(text)
text
# Out:
# ['i',
#  'love',
#  'machine',
#  'leaning',
#  'ai',
#  'it',
#  'is',
#  'best',
#  'thing',
#  'to',
#  'learn',
#  'in']

# %%
from nltk.corpus import stopwords

clean_text = []
stopword_list = stopwords.words('english')
for word in text:
    if word not in stopword_list:
        clean_text.append(word)

# %%
text = [word for word in text if word not in stopwords.words('english')]

# %%
text
# Out:
# ['love', 'machine', 'leaning', 'ai', 'best', 'thing', 'learn']
